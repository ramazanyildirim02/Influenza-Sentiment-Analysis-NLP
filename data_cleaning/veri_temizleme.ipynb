# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("kirli_data.xlsx")
data
# Out:
#        Unnamed: 0                                                  0
# 0               0  Grip, influenza virusuna bağlı bir solunum yol...
# 1               1  Hafif bir üst solunum yolu enfeksiyonundan, öl...
# 2               2  Grip, tipik olarak ani başlayan ateş, titreme,...
# 3               3  İnfluenza virusları, Orthomyxoviridae ailesi i...
# 4               4  İnsanlarda en sık hastalık yapan tipler influe...
# ...           ...                                                ...
# 10600       10600                                                NaN
# 10601       10601                                                NaN
# 10602       10602                                                NaN
# 10603       10603                                                NaN
# 10604       10604                                                NaN
#
# [10605 rows x 2 columns]

# %%
data["Unnamed: 0"] = np.arange(1,len(data) +1 )

# %%
data.iloc[:,1]
# Out:
# 0        Grip, influenza virusuna bağlı bir solunum yol...
# 1        Hafif bir üst solunum yolu enfeksiyonundan, öl...
# 2        Grip, tipik olarak ani başlayan ateş, titreme,...
# 3        İnfluenza virusları, Orthomyxoviridae ailesi i...
# 4        İnsanlarda en sık hastalık yapan tipler influe...
#                                ...
# 10600                                                  NaN
# 10601                                                  NaN
# 10602                                                  NaN
# 10603                                                  NaN
# 10604                                                  NaN
# Name: 0, Length: 10605, dtype: object

# %%
len(data)
# Out:
# 10605

# %%
data
# Out:
#        Unnamed: 0                                                  0
# 0               1  Grip, influenza virusuna bağlı bir solunum yol...
# 1               2  Hafif bir üst solunum yolu enfeksiyonundan, öl...
# 2               3  Grip, tipik olarak ani başlayan ateş, titreme,...
# 3               4  İnfluenza virusları, Orthomyxoviridae ailesi i...
# 4               5  İnsanlarda en sık hastalık yapan tipler influe...
# ...           ...                                                ...
# 10600       10601                                                NaN
# 10601       10602                                                NaN
# 10602       10603                                                NaN
# 10603       10604                                                NaN
# 10604       10605                                                NaN
#
# [10605 rows x 2 columns]

# %%
data = data.rename(columns={'Unnamed: 0': 'Cumle sayisi'})

# %%
data
# Out:
#        Cumle sayisi                                                  0
# 0                 1  Grip, influenza virusuna bağlı bir solunum yol...
# 1                 2  Hafif bir üst solunum yolu enfeksiyonundan, öl...
# 2                 3  Grip, tipik olarak ani başlayan ateş, titreme,...
# 3                 4  İnfluenza virusları, Orthomyxoviridae ailesi i...
# 4                 5  İnsanlarda en sık hastalık yapan tipler influe...
# ...             ...                                                ...
# 10600         10601                                                NaN
# 10601         10602                                                NaN
# 10602         10603                                                NaN
# 10603         10604                                                NaN
# 10604         10605                                                NaN
#
# [10605 rows x 2 columns]

# %%
data.to_excel("ham_corpus.xlsx")

# %%
import re

import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/macbook/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
clean_data = []

for i in range(10190):
    datas = re.sub("[^a-zA-Z]"," ",str(data.iloc[i,1])) # removing alphanumerical characters
    datas = datas.lower().split()
    datas = [word for word in datas if not word in set(stopwords.words("turkish"))] # removing stopwords and suffixes
    datas = " ".join(datas) 
    clean_data.append(datas)

# %%
clean_data
# Out:
# ['grip influenza virusuna ba l bir solunum yolu enfeksiyonudur',
#  'hafif bir st solunum yolu enfeksiyonundan l me olan a r bir alt solunum yolu enfeksiyonuna kadar i klinik g sterir',
#  'grip tipik olarak ani ba layan ate titreme ba a r s yayg n kas a r s ks r k karakterize solunum yolu enfeksiyonudur',
#  'nfluenza viruslar orthomyxoviridae ailesi i erisinde yer alan influenza a influenza b influenza c son y llarda tan mlanan influenza d dir',
#  'nsanlarda s k hastal k yapan tipler influenza a b dir',
#  'nfluenza pandemiler seyredebilir',
#  'son influenza pandemisi y l nda h n g r lm t r',
#  'nfluenza enfeksiyonu iden iye primer olarak ks r k hap rma solunum yolu damlac klar yoluyla bula r',
#  'nfluenza tedavisi destek tedavisi antiviral tedaviden olu maktad r',
#  'komplike a r hastal k varl nda y ksek risk grubu hastalarda hastanede yatan hastalarda erken zellikle ilk saat i inde antiviral tedavi ba lanmas prognozda ok nemlidir',
#  'esas korunma yolu a lanmad r',
# ...

# %%
data =  data.dropna()

# %%
data[0]
# Out:
# 0        Grip, influenza virusuna bağlı bir solunum yol...
# 1        Hafif bir üst solunum yolu enfeksiyonundan, öl...
# 2        Grip, tipik olarak ani başlayan ateş, titreme,...
# 3        İnfluenza virusları, Orthomyxoviridae ailesi i...
# 4        İnsanlarda en sık hastalık yapan tipler influe...
#                                ...
# 10574    Ancak çalışmamızda altta yatan hastalığı olan ...
# 10575    Çalışmamızda ayrıca influ enza aşısının altta ...
# 10576    Katılımcıların %77’si influenza aşısını aile h...
# 10577    Ankete katılan kişilerin grip aşısının varlığı...
# 10578    Göğüs hastalıkları ve enfek siyon hastalıkları...
# Name: 0, Length: 10263, dtype: object

# %%
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


# Fonksiyonlar tanımlama
def clean_text(text):
    # Nümerik ifadeleri kaldırma
    text = re.sub(r'\d+', '', text)
    
    # Özel karakterleri ve noktalama işaretlerini kaldırma
    text = re.sub(r'[^\w\s]', '', text)
    
    # Stopwords'leri kaldırma
    stop_words = set(stopwords.words('turkish'))
    words = word_tokenize(text)
    filtered_words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]
    
    # Sonucu birleştirme
    cleaned_text = " ".join(filtered_words)
    
    return cleaned_text

data['Cleaned_Text'] = data[0].apply(clean_text)
# Out:
# /var/folders/l4/pchdf7b10cs1t5kx4kd2j97h0000gn/T/ipykernel_2177/1508065300.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cleaned_Text'] = data[0].apply(clean_text)

# %%
  >>> nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/macbook/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data
# Out:
#        Cumle sayisi                                                  0  \
# 0                 1  Grip, influenza virusuna bağlı bir solunum yol...
# 1                 2  Hafif bir üst solunum yolu enfeksiyonundan, öl...
# 2                 3  Grip, tipik olarak ani başlayan ateş, titreme,...
# 3                 4  İnfluenza virusları, Orthomyxoviridae ailesi i...
# 4                 5  İnsanlarda en sık hastalık yapan tipler influe...
# ...             ...                                                ...
# 10574         10575  Ancak çalışmamızda altta yatan hastalığı olan ...
# 10575         10576  Çalışmamızda ayrıca influ enza aşısının altta ...
# 10576         10577  Katılımcıların %77’si influenza aşısını aile h...
# 10577         10578  Ankete katılan kişilerin grip aşısının varlığı...
# 10578         10579  Göğüs hastalıkları ve enfek siyon hastalıkları...
#
#                                             Cleaned_Text
# 0      grip influenza virusuna bağlı bir solunum yolu...
# ...

# %%
new_data = data.drop(0,axis = 1)
new_data
# Out:
#        Cumle sayisi                                       Cleaned_Text
# 0                 1  grip influenza virusuna bağlı bir solunum yolu...
# 1                 2  hafif bir üst solunum yolu enfeksiyonundan ölü...
# 2                 3  grip tipik olarak ani başlayan ateş titreme ba...
# 3                 4  i̇nfluenza virusları orthomyxoviridae ailesi i...
# 4                 5  i̇nsanlarda sık hastalık yapan tipler influenz...
# ...             ...                                                ...
# 10574         10575  ancak çalışmamızda altta yatan hastalığı olan ...
# 10575         10576  çalışmamızda ayrıca influ enza aşısının altta ...
# 10576         10577  katılımcıların si influenza aşısını aile hekim...
# 10577         10578  ankete katılan kişilerin grip aşısının varlığı...
# 10578         10579  göğüs hastalıkları enfek siyon hastalıkları uz...
#
# [10263 rows x 2 columns]

# %%
new_data.to_excel("derlenmis_corpus.xlsx")
